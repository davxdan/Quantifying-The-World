# %%
import os
os.getcwd()
import pandas as pd
import numpy as np


cbWomenDF = pd.read_csv('cbWomenDF.csv')

# %%
import seaborn as sns
from matplotlib import pyplot

# %%
a4_dims = (11.7, 8.27)
sns.set(style="whitegrid")
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.violinplot(y=cbWomenDF.age, x=cbWomenDF.year, data=cbWomenDF)

# %%
cbWomenDF.age
# Out:
# 0        26
# 1        29
# 2        20
# 3        29
# 4        24
# 5        38
# 6        27
# 7        30
# 8        30
# 9        37
# 10       39
# 11       32
# 12       30
# 13       31
# 14       25
# 15       38
# 16       31
# 17       36
# 18       30
# 19       40
# 20       34
# 21       37
# 22       29
# 23       34
# 24       33
# 25       30
# 26       24
# 27       39
# 28       31
# 29       34
#          ..
# 76008    44
# 76009    29
# 76010    40
# 76011    33
# 76012    62
# 76013    34
# 76014    30
# 76015    39
# 76016    33
# 76017    54
# 76018    47
# 76019    50
# 76020    28
# 76021    37
# 76022    41
# 76023    32
# 76024    64
# 76025    44
# 76026    31
# 76027    27
# 76028    33
# 76029    39
# 76030    38
# 76031    33
# 76032    39
# 76033    40
# 76034    31
# 76035    55
# 76036    40
# 76037    38
# Name: age, Length: 76038, dtype: int64
